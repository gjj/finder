# %% [markdown]
# # Finder2
#
# From [this Medium article](https://towardsdatascience.com/deep-learning-magic-small-business-type-8ac484d8c3bf) and [this repository](https://github.com/lemay-ai/smallCompanyType2.0).

# %%
from keras.models import load_model  
from os import path
import sys
import pandas as pd

# %%
import smallCompanyType as s

# %%
b = s.SmallCompanyType()
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
input_file = "20210311_v0.2-FSI" # no need for file extension
df = pd.read_csv("{}.csv".format(input_file))

entity_names = df['Entity Name']

for text in entity_names:
    ctype = b.getCompanyType(text)
    csubtype = b.getCompanySubtype(text)
    print(text,"is a",ctype,csubtype)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-24960e4ccf98> in <module>
#       6 for text in entity_names:
#       7 #     ctype = b.getCompanyType(text)
# ----> 8     csubtype = b.getCompanySubtype(text)
#       9     print(text,"is a",ctype,csubtype)
#
# D:\Users\goijj\anaconda3\lib\site-packages\smallcompanytype-1.0-py3.8.egg\smallCompanyType\smallCompanyType.py in getCompanySubtype(self, name)
#     164     # Predict and return a categorical label for an input company name string
#     165     def getCompanySubtype(self, name):
# --> 166         sample=self.getCompanyVector(name)
#     167         sampleMod = sample[np.newaxis,:]
#     168         predicted = (self.dnn_model.predict(sampleMod)[0])
#
# D:\Users\goijj\anaconda3\lib\site-packages\smallcompanytype-1.0-py3.8.egg\smallCompanyType\smallCompanyType.py in getCompanyVector(self, name)
#     155         wordCount=0
#     156         for word in name.split():
# --> 157             if word in self.embedding_model:
#     158                 overallVec=np.add(self.embedding_model[word],overallVec)
#     159                 wordCount+=1
#
# TypeError: argument of type 'Word2Vec' is not iterable
